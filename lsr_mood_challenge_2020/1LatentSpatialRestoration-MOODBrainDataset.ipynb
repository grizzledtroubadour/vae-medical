# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import nibabel as nib

import pickle

import preprocessing
import utils
import nets_LV

from utils import img_extended

from sklearn import metrics
from skimage.transform import resize

import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = [5.0, 5.0]
plt.rcParams['figure.dpi'] = 120
plt.rcParams['savefig.dpi'] = 100

plt.rcParams['font.size'] = 8
plt.rcParams['legend.fontsize'] = 'small'
plt.rcParams['figure.titlesize'] = 'medium'

plt.rcParams['lines.linewidth'] = 1

# %% [markdown]
# ## Dataset

# %%
from torch.utils.data import DataLoader

train_dir = os.path.expanduser('~/.cache/autoencoders/data/MOODBrain_train/data/')
holdout_dir = os.path.expanduser('~/.cache/autoencoders/data/MOODBrain_train/data/')

train_dset = preprocessing.brain_dataset(data_dir=train_dir, sample_number = 8, train = True)
train_loader = DataLoader(train_dset, batch_size=8,shuffle=True,num_workers=8,
                         collate_fn = preprocessing.collate_fn)

holdout_dset = preprocessing.brain_dataset(data_dir=holdout_dir, sample_number = 8, train = False)
holdout_loader = DataLoader(holdout_dset, batch_size=8,shuffle=True,num_workers=8,
                         collate_fn = preprocessing.collate_fn)

# %% [markdown]
# Retrieve a sample (8 slices from 8 volumes)

# %%
X_hl = next(iter(holdout_loader))

# %% [markdown]
# Images are in the attribute img of the img_extended object. Coordinates are in coord (used to condition both VQ-VAE and AR)

# %%
print(X_hl.img.shape)
print(X_hl.coord.shape)
# Out:
# (64, 160, 160)
# (64, 1)

# %%
plt.imshow(X_hl.img[42])
plt.axis('off')
# Out:
# (-0.5, 159.5, 159.5, -0.5)

# %% [markdown]
# # Model training
# ## VQ-VAE
#
# Training of VQ-VAE network.

# %%
device = torch.device('cuda')

# %%
model = nets_LV.VQVAE(1,n_channels=(16,32,64,256),code_size=128,n_res_block=2,cond_channels=1,dropout_p=.1)

model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
tracker = utils.train_tracker()

# %%
utils.train_epochs(model, optimizer, tracker, train_loader, holdout_loader, epochs=600, device = device,)
# Out:
# 1 epochs, 2.770 test loss, 5.165 train loss
# 2 epochs, 3.028 test loss, 5.597 train loss
# 3 epochs, 3.160 test loss, 4.836 train loss
# 4 epochs, 2.509 test loss, 3.763 train loss
# 5 epochs, 2.165 test loss, 2.937 train loss
# 6 epochs, 1.950 test loss, 2.348 train loss
# 7 epochs, 1.648 test loss, 1.968 train loss
# 8 epochs, 1.511 test loss, 1.716 train loss
# 11 epochs, 1.138 test loss, 1.247 train loss
# 12 epochs, 1.109 test loss, 1.166 train loss
# 13 epochs, 1.072 test loss, 1.080 train loss
# 14 epochs, 0.955 test loss, 0.994 train loss
# 15 epochs, 0.929 test loss, 0.931 train loss
# 16 epochs, 0.845 test loss, 0.868 train loss
# 17 epochs, 0.815 test loss, 0.828 train loss
# 18 epochs, 0.782 test loss, 0.773 train loss
# 19 epochs, 0.740 test loss, 0.745 train loss
# 20 epochs, 0.709 test loss, 0.704 train loss
# 21 epochs, 0.675 test loss, 0.668 train loss
# 22 epochs, 0.667 test loss, 0.635 train loss
# 23 epochs, 0.618 test loss, 0.594 train loss
# 24 epochs, 0.601 test loss, 0.565 train loss
# 25 epochs, 0.571 test loss, 0.536 train loss
# 26 epochs, 0.548 test loss, 0.507 train loss
# 27 epochs, 0.516 test loss, 0.487 train loss
# 28 epochs, 0.511 test loss, 0.473 train loss
# 29 epochs, 0.469 test loss, 0.452 train loss
# 30 epochs, 0.481 test loss, 0.437 train loss
# 31 epochs, 0.449 test loss, 0.422 train loss
# 32 epochs, 0.446 test loss, 0.409 train loss
# 33 epochs, 0.439 test loss, 0.397 train loss
# 34 epochs, 0.426 test loss, 0.383 train loss
# 35 epochs, 0.420 test loss, 0.372 train loss
# 36 epochs, 0.396 test loss, 0.360 train loss
# 37 epochs, 0.394 test loss, 0.355 train loss
# 38 epochs, 0.386 test loss, 0.347 train loss
# 39 epochs, 0.370 test loss, 0.334 train loss
# 40 epochs, 0.361 test loss, 0.325 train loss
# 41 epochs, 0.363 test loss, 0.314 train loss
# 42 epochs, 0.354 test loss, 0.312 train loss
# 43 epochs, 0.348 test loss, 0.306 train loss
# 44 epochs, 0.350 test loss, 0.300 train loss
# 45 epochs, 0.338 test loss, 0.290 train loss
# 46 epochs, 0.322 test loss, 0.285 train loss
# 47 epochs, 0.317 test loss, 0.280 train loss
# 48 epochs, 0.318 test loss, 0.276 train loss
# 49 epochs, 0.308 test loss, 0.270 train loss
# 50 epochs, 0.303 test loss, 0.266 train loss
# 51 epochs, 0.303 test loss, 0.260 train loss
# 52 epochs, 0.293 test loss, 0.256 train loss
# 53 epochs, 0.287 test loss, 0.252 train loss
# 54 epochs, 0.288 test loss, 0.249 train loss
# 55 epochs, 0.281 test loss, 0.247 train loss
# 56 epochs, 0.283 test loss, 0.240 train loss
# 57 epochs, 0.281 test loss, 0.237 train loss
# 58 epochs, 0.274 test loss, 0.236 train loss
# 59 epochs, 0.272 test loss, 0.232 train loss
# 60 epochs, 0.267 test loss, 0.226 train loss
# 61 epochs, 0.263 test loss, 0.226 train loss
# 62 epochs, 0.267 test loss, 0.221 train loss
# 63 epochs, 0.258 test loss, 0.219 train loss
# 64 epochs, 0.256 test loss, 0.217 train loss
# 65 epochs, 0.251 test loss, 0.213 train loss
# 66 epochs, 0.249 test loss, 0.210 train loss
# 67 epochs, 0.247 test loss, 0.211 train loss
# 68 epochs, 0.244 test loss, 0.205 train loss
# 69 epochs, 0.239 test loss, 0.204 train loss
# 70 epochs, 0.243 test loss, 0.202 train loss
# 71 epochs, 0.237 test loss, 0.199 train loss
# 72 epochs, 0.238 test loss, 0.197 train loss
# 73 epochs, 0.240 test loss, 0.195 train loss
# 74 epochs, 0.234 test loss, 0.194 train loss
# 75 epochs, 0.232 test loss, 0.192 train loss
# 76 epochs, 0.230 test loss, 0.193 train loss
# 77 epochs, 0.227 test loss, 0.191 train loss
# 78 epochs, 0.229 test loss, 0.186 train loss
# 79 epochs, 0.227 test loss, 0.187 train loss
# 80 epochs, 0.224 test loss, 0.184 train loss
# 81 epochs, 0.223 test loss, 0.184 train loss
# 82 epochs, 0.218 test loss, 0.182 train loss
# 83 epochs, 0.225 test loss, 0.182 train loss
# 84 epochs, 0.219 test loss, 0.181 train loss
# 85 epochs, 0.224 test loss, 0.180 train loss
# 86 epochs, 0.219 test loss, 0.179 train loss
# 87 epochs, 0.214 test loss, 0.177 train loss
# 88 epochs, 0.217 test loss, 0.176 train loss
# 89 epochs, 0.215 test loss, 0.176 train loss
# 90 epochs, 0.212 test loss, 0.174 train loss
# 91 epochs, 0.217 test loss, 0.171 train loss
# 92 epochs, 0.213 test loss, 0.172 train loss
# 93 epochs, 0.209 test loss, 0.170 train loss
# 94 epochs, 0.213 test loss, 0.169 train loss
# 95 epochs, 0.210 test loss, 0.170 train loss
# 96 epochs, 0.205 test loss, 0.168 train loss
# 97 epochs, 0.208 test loss, 0.165 train loss
# 98 epochs, 0.207 test loss, 0.165 train loss
# 99 epochs, 0.206 test loss, 0.168 train loss
# 100 epochs, 0.205 test loss, 0.166 train loss
# 101 epochs, 0.205 test loss, 0.161 train loss
# 102 epochs, 0.204 test loss, 0.165 train loss
# 103 epochs, 0.202 test loss, 0.160 train loss
# 104 epochs, 0.203 test loss, 0.162 train loss
# 105 epochs, 0.204 test loss, 0.161 train loss
# 106 epochs, 0.200 test loss, 0.158 train loss
# 107 epochs, 0.201 test loss, 0.158 train loss
# 108 epochs, 0.198 test loss, 0.161 train loss
# 109 epochs, 0.201 test loss, 0.159 train loss
# 110 epochs, 0.197 test loss, 0.158 train loss
# 111 epochs, 0.200 test loss, 0.157 train loss
# 112 epochs, 0.197 test loss, 0.157 train loss
# 113 epochs, 0.199 test loss, 0.157 train loss
# 114 epochs, 0.195 test loss, 0.157 train loss
# 115 epochs, 0.194 test loss, 0.155 train loss
# 116 epochs, 0.193 test loss, 0.154 train loss
# 117 epochs, 0.196 test loss, 0.153 train loss
# 118 epochs, 0.195 test loss, 0.153 train loss
# 119 epochs, 0.195 test loss, 0.153 train loss
# 120 epochs, 0.193 test loss, 0.154 train loss
# 121 epochs, 0.195 test loss, 0.151 train loss
# 122 epochs, 0.190 test loss, 0.150 train loss
# 123 epochs, 0.192 test loss, 0.152 train loss
# 124 epochs, 0.192 test loss, 0.149 train loss
# 125 epochs, 0.189 test loss, 0.148 train loss
# 126 epochs, 0.191 test loss, 0.149 train loss
# 127 epochs, 0.189 test loss, 0.149 train loss
# 128 epochs, 0.189 test loss, 0.149 train loss
# 129 epochs, 0.191 test loss, 0.148 train loss
# 130 epochs, 0.188 test loss, 0.146 train loss
# 131 epochs, 0.188 test loss, 0.145 train loss
# 132 epochs, 0.190 test loss, 0.147 train loss
# 133 epochs, 0.192 test loss, 0.145 train loss
# 134 epochs, 0.185 test loss, 0.147 train loss
# 135 epochs, 0.188 test loss, 0.145 train loss
# 136 epochs, 0.184 test loss, 0.143 train loss
# 137 epochs, 0.185 test loss, 0.144 train loss
# 138 epochs, 0.186 test loss, 0.143 train loss
# 139 epochs, 0.187 test loss, 0.141 train loss
# 140 epochs, 0.183 test loss, 0.144 train loss
# 141 epochs, 0.182 test loss, 0.142 train loss
# 142 epochs, 0.183 test loss, 0.141 train loss
# 143 epochs, 0.184 test loss, 0.142 train loss
# 144 epochs, 0.181 test loss, 0.141 train loss
# 145 epochs, 0.184 test loss, 0.140 train loss
# 146 epochs, 0.183 test loss, 0.141 train loss
# 147 epochs, 0.183 test loss, 0.139 train loss
# 148 epochs, 0.179 test loss, 0.139 train loss
# 149 epochs, 0.180 test loss, 0.140 train loss
# 150 epochs, 0.182 test loss, 0.140 train loss
# 151 epochs, 0.181 test loss, 0.138 train loss
# 152 epochs, 0.183 test loss, 0.138 train loss
# 153 epochs, 0.182 test loss, 0.137 train loss
# 154 epochs, 0.180 test loss, 0.137 train loss
# 155 epochs, 0.180 test loss, 0.137 train loss
# 156 epochs, 0.178 test loss, 0.135 train loss
# 157 epochs, 0.179 test loss, 0.136 train loss
# 158 epochs, 0.179 test loss, 0.136 train loss
# 159 epochs, 0.178 test loss, 0.136 train loss
# 160 epochs, 0.179 test loss, 0.135 train loss
# 161 epochs, 0.176 test loss, 0.136 train loss
# 162 epochs, 0.179 test loss, 0.134 train loss
# 163 epochs, 0.178 test loss, 0.135 train loss
# 164 epochs, 0.176 test loss, 0.135 train loss
# 165 epochs, 0.175 test loss, 0.135 train loss
# 166 epochs, 0.178 test loss, 0.132 train loss
# 167 epochs, 0.176 test loss, 0.133 train loss
# 168 epochs, 0.176 test loss, 0.134 train loss
# 169 epochs, 0.177 test loss, 0.134 train loss
# 170 epochs, 0.176 test loss, 0.133 train loss
# 171 epochs, 0.173 test loss, 0.134 train loss
# 172 epochs, 0.175 test loss, 0.133 train loss
# 173 epochs, 0.173 test loss, 0.131 train loss
# 174 epochs, 0.174 test loss, 0.132 train loss
# 175 epochs, 0.176 test loss, 0.132 train loss
# 176 epochs, 0.173 test loss, 0.131 train loss
# 177 epochs, 0.175 test loss, 0.133 train loss
# 178 epochs, 0.175 test loss, 0.129 train loss
# 179 epochs, 0.174 test loss, 0.131 train loss
# 180 epochs, 0.172 test loss, 0.129 train loss
# 181 epochs, 0.173 test loss, 0.130 train loss
# 182 epochs, 0.175 test loss, 0.131 train loss
# 183 epochs, 0.173 test loss, 0.130 train loss
# 184 epochs, 0.174 test loss, 0.130 train loss
# 185 epochs, 0.171 test loss, 0.130 train loss
# 186 epochs, 0.170 test loss, 0.129 train loss
# 187 epochs, 0.171 test loss, 0.129 train loss
# 188 epochs, 0.170 test loss, 0.130 train loss
# 189 epochs, 0.172 test loss, 0.129 train loss
# 190 epochs, 0.174 test loss, 0.128 train loss
# 191 epochs, 0.170 test loss, 0.127 train loss
# 192 epochs, 0.170 test loss, 0.129 train loss
# 194 epochs, 0.170 test loss, 0.127 train loss
# 195 epochs, 0.170 test loss, 0.128 train loss
# 196 epochs, 0.172 test loss, 0.128 train loss
# 197 epochs, 0.167 test loss, 0.126 train loss
# 198 epochs, 0.169 test loss, 0.126 train loss
# 199 epochs, 0.168 test loss, 0.125 train loss
# 200 epochs, 0.168 test loss, 0.126 train loss
# 201 epochs, 0.167 test loss, 0.126 train loss
# 202 epochs, 0.170 test loss, 0.126 train loss
# 203 epochs, 0.167 test loss, 0.125 train loss
# 204 epochs, 0.167 test loss, 0.125 train loss
# 205 epochs, 0.166 test loss, 0.126 train loss
# 206 epochs, 0.168 test loss, 0.127 train loss
# 207 epochs, 0.168 test loss, 0.124 train loss
# 208 epochs, 0.167 test loss, 0.126 train loss
# 209 epochs, 0.166 test loss, 0.124 train loss
# 210 epochs, 0.167 test loss, 0.123 train loss
# 211 epochs, 0.166 test loss, 0.124 train loss
# 212 epochs, 0.169 test loss, 0.123 train loss
# 213 epochs, 0.169 test loss, 0.123 train loss
# 214 epochs, 0.164 test loss, 0.123 train loss
# 215 epochs, 0.165 test loss, 0.123 train loss
# 216 epochs, 0.168 test loss, 0.123 train loss
# 217 epochs, 0.166 test loss, 0.125 train loss
# 218 epochs, 0.164 test loss, 0.122 train loss
# 219 epochs, 0.164 test loss, 0.122 train loss
# 220 epochs, 0.166 test loss, 0.122 train loss
# 221 epochs, 0.164 test loss, 0.122 train loss
# 222 epochs, 0.165 test loss, 0.123 train loss
# 223 epochs, 0.164 test loss, 0.123 train loss
# 224 epochs, 0.166 test loss, 0.122 train loss
# 225 epochs, 0.164 test loss, 0.121 train loss

# %%
tracker.plot(500)

# %% [markdown]
# Utility below allows to save / load checkpoints of the training. Note that when training Prior AR below, VQ-VAE model parameters will be loaded from a checkpint

# %%
ckpt_dir = os.path.expanduser("~/experience/lsr_master/checkpoints")
os.makedirs(ckpt_dir, exist_ok=True)
utils.save_checkpoint(model, optimizer, tracker, os.path.join(ckpt_dir, "brain_vqvae.pt"))

# %% [markdown]
# ## Prior AR
# Definition and training of prior model. feat_ext_mdl is the vq-vae network that must have been trained in section above, its weights are loaded from checkpoint

# %%
feat_ext_mdl = nets_LV.VQVAE(1,n_channels=(16,32,64,256),code_size=128,n_res_block=2,cond_channels=1, dropout_p=.1)

feat_ext_mdl.to(device)
chpt = torch.load(os.path.join(ckpt_dir, "brain_vqvae.pt"))
feat_ext_mdl.load_state_dict(chpt['model'])

model = nets_LV.VQLatentSNAIL(feature_extractor_model=feat_ext_mdl,
                              shape=(20,20), n_block = 4, n_res_block = 4, n_channels = 128, cond_channels=1)
model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
tracker = utils.train_tracker()

# %%
utils.train_epochs(model, optimizer, tracker, train_loader, holdout_loader, epochs=600, device = device,)
# Out:
# 1 epochs, 2.804 test loss, 3.326 train loss
# 2 epochs, 2.680 test loss, 2.671 train loss
# 3 epochs, 2.650 test loss, 2.610 train loss
# 4 epochs, 2.626 test loss, 2.595 train loss
# 5 epochs, 2.609 test loss, 2.567 train loss
# 6 epochs, 2.612 test loss, 2.533 train loss
# 7 epochs, 2.560 test loss, 2.522 train loss
# 8 epochs, 2.597 test loss, 2.519 train loss
# 9 epochs, 2.541 test loss, 2.476 train loss
# 10 epochs, 2.552 test loss, 2.466 train loss
# 11 epochs, 2.532 test loss, 2.467 train loss
# 12 epochs, 2.515 test loss, 2.435 train loss
# 13 epochs, 2.496 test loss, 2.439 train loss
# 14 epochs, 2.469 test loss, 2.421 train loss
# 15 epochs, 2.460 test loss, 2.427 train loss
# 16 epochs, 2.458 test loss, 2.425 train loss
# 17 epochs, 2.458 test loss, 2.403 train loss
# 18 epochs, 2.466 test loss, 2.395 train loss
# 19 epochs, 2.442 test loss, 2.373 train loss
# 20 epochs, 2.423 test loss, 2.396 train loss
# 21 epochs, 2.421 test loss, 2.376 train loss
# 22 epochs, 2.424 test loss, 2.366 train loss
# 23 epochs, 2.414 test loss, 2.353 train loss
# 24 epochs, 2.421 test loss, 2.348 train loss
# 25 epochs, 2.413 test loss, 2.346 train loss
# 26 epochs, 2.396 test loss, 2.360 train loss
# 27 epochs, 2.410 test loss, 2.366 train loss
# 28 epochs, 2.395 test loss, 2.365 train loss
# 29 epochs, 2.374 test loss, 2.355 train loss
# 30 epochs, 2.382 test loss, 2.342 train loss
# 31 epochs, 2.382 test loss, 2.321 train loss
# 32 epochs, 2.382 test loss, 2.339 train loss
# 33 epochs, 2.368 test loss, 2.334 train loss
# 34 epochs, 2.380 test loss, 2.328 train loss
# 35 epochs, 2.343 test loss, 2.335 train loss
# 36 epochs, 2.369 test loss, 2.337 train loss
# 37 epochs, 2.356 test loss, 2.306 train loss
# 38 epochs, 2.351 test loss, 2.311 train loss
# 39 epochs, 2.352 test loss, 2.318 train loss
# 40 epochs, 2.376 test loss, 2.306 train loss
# 41 epochs, 2.354 test loss, 2.323 train loss
# 42 epochs, 2.356 test loss, 2.295 train loss
# 43 epochs, 2.340 test loss, 2.313 train loss
# 44 epochs, 2.358 test loss, 2.295 train loss
# 45 epochs, 2.347 test loss, 2.292 train loss
# 46 epochs, 2.351 test loss, 2.287 train loss
# 47 epochs, 2.337 test loss, 2.285 train loss
# 48 epochs, 2.334 test loss, 2.281 train loss
# 49 epochs, 2.338 test loss, 2.291 train loss
# 50 epochs, 2.326 test loss, 2.273 train loss
# 51 epochs, 2.329 test loss, 2.268 train loss
# 53 epochs, 2.310 test loss, 2.292 train loss
# 54 epochs, 2.310 test loss, 2.287 train loss
# 55 epochs, 2.306 test loss, 2.279 train loss
# 56 epochs, 2.309 test loss, 2.268 train loss
# 57 epochs, 2.311 test loss, 2.265 train loss
# 58 epochs, 2.330 test loss, 2.249 train loss
# 59 epochs, 2.320 test loss, 2.255 train loss
# 60 epochs, 2.302 test loss, 2.244 train loss
# 61 epochs, 2.294 test loss, 2.225 train loss
# 62 epochs, 2.312 test loss, 2.269 train loss
# 63 epochs, 2.293 test loss, 2.246 train loss
# 64 epochs, 2.281 test loss, 2.234 train loss
# 65 epochs, 2.286 test loss, 2.258 train loss
# 66 epochs, 2.281 test loss, 2.243 train loss
# 67 epochs, 2.289 test loss, 2.231 train loss
# 68 epochs, 2.263 test loss, 2.237 train loss
# 69 epochs, 2.287 test loss, 2.240 train loss
# 70 epochs, 2.281 test loss, 2.239 train loss
# 71 epochs, 2.272 test loss, 2.227 train loss
# 72 epochs, 2.285 test loss, 2.236 train loss
# 73 epochs, 2.251 test loss, 2.228 train loss
# 74 epochs, 2.272 test loss, 2.225 train loss
# 75 epochs, 2.254 test loss, 2.221 train loss
# 76 epochs, 2.266 test loss, 2.231 train loss
# 77 epochs, 2.254 test loss, 2.212 train loss

# %%
tracker.plot(300)

# %%
utils.save_checkpoint(model, optimizer, tracker, os.path.join(ckpt_dir, "brain_prior.pt"))

# %% [markdown]
# # Anomaly detection
# ## Loading of toy examples
#
# Only 32 slices for each volume are processed:

# %%
def load_volume_brain(source_file, slices = 32):
        nimg = nib.load(source_file)
        nimg_array = nimg.get_fdata()
        vol_s = nimg_array.shape

        nimg_array = resize(nimg_array, (160, 160, slices))
        nimg_array = nimg_array.transpose((2,1,0))
        nimg_array = nimg_array[:, ::-1, :]
        
        # Normalize non-zeros
        nimg_array[nimg_array<0.05] = 0

        non_zero_mask = np.where(nimg_array>0.05)
        mu,sigma = nimg_array[non_zero_mask].mean(),nimg_array[non_zero_mask].std()
        nimg_array[non_zero_mask] = (nimg_array[non_zero_mask] - mu) / (sigma+1e-5)
        
        coord = np.linspace(-.5,.5,slices)[:, np.newaxis]
        
        img_batch = img_extended(nimg_array,
                                   np.zeros(slices,dtype='uint8'),
                                   np.zeros(slices,dtype='uint8'),
                                   np.zeros(slices,dtype='uint8'),
                                   coord,
                                   np.zeros(slices,dtype='uint8'),
                                  )
        
        return img_batch, vol_s, nimg.affine

def load_seg_brain(source_file, slices = 32):
        nimg = nib.load(source_file)
        nimg_array = nimg.get_fdata()
        vol_s = nimg_array.shape

        nimg_array = resize(nimg_array, (160, 160, slices))
        nimg_array = nimg_array.transpose((2,1,0))
        nimg_array = nimg_array[:, ::-1, :]
        nimg_array = (nimg_array > .5)
        return nimg_array
    
toy_dir = os.path.expanduser('~/.cache/autoencoders/data/MOODBrain_toy/data/toy')
toy_seg_dir = os.path.expanduser('~/.cache/autoencoders/data/MOODBrain_train/data/')mood/data_toy/brain/toy_label/pixel'

mood_test = []
mood_test_seg = []

for i in range(4):
    mood_test.append(load_volume_brain(os.path.join(toy_dir,'toy_{}.nii.gz'.format(i)))[0])
    mood_test_seg.append(load_seg_brain(os.path.join(toy_seg_dir,'toy_{}.nii.gz'.format(i))))

# %%
# Shape of image / segmentation (32,160,160)
print(mood_test[0].img.shape)
print(mood_test_seg[0].shape)

# %% [markdown]
# ## Sample-wise score
#
#
# Sample-wise score is derived from the density of the latent variables as estimated by the AR prior model. Specifically, we hypothesize that the prior model will assign low probability to the latent variables encoding image areas where anomalies exist.
#
# We use as score the estimated cross-entropy for the latent variables, considering only the values for the latent variables with cross-entropy above a threshold λ. The 98 percentile of the cross-entropy values observed in the holdout dataset has been used as threshold, in both datasets this corresponded broadly to the value 7.
#
# $$Score_{sample} = \sum_{i=1}^N \xi(p(x))$$
#
# $$
# \xi(z) = \begin{cases}
#      -\log(z) \text{ if} -\log(z) > \lambda \\
#      0 \text{ otherwise} \\
#     \end{cases}
# $$

# %%
pred = []

model.eval()
for X in mood_test:
    x_img = torch.from_numpy(X.img.copy()).to(device).float()
    x_coord = torch.from_numpy(X.coord).to(device).float()

    with torch.no_grad():
        codes = model.retrieve_codes(x_img,x_coord).flatten(1)
        loss = model.loss(x_img,cond = x_coord, reduction='none')['loss'].flatten(1)
        
        score = torch.sum(loss*(loss>7),1).float()
        pred.append([score.cpu().numpy()])

pred = np.concatenate(pred,1).reshape(4,32)

# %%
# Print a slice no [0,32] for each of the volumes with the scores for the slice
no = 10
fig,ax = plt.subplots(1,4,figsize = (8,8))

[a.imshow(mood_test[i].img[no],vmin=-3,vmax=3) for i,a in enumerate(ax)]
[a.set_title('Score {:.1f}'.format(pred[i,no])) for i,a in enumerate(ax)]
[a.axis('off') for a in ax]
plt.tight_layout()

# %% [markdown]
# In the docker submission, slice scores are normalized dividing by 200 and clipping to 1.
#
# The score for the volume is just the sum of the slices.

# %%
pred.sum(1)

# %% [markdown]
# ## Pixel-wise scores
#
# Pixel-wise score also utilizes densities estimated by the AR model. We restore anomalous slices by replacing high-loss latent codes with low-loss codes sampled by the AR model and decoding to pixel space using the VQ-VAE decoder.
#
# This process generates restorations of the original image, where encoded areas with low probability are replaced with normal areas as observed in the training set. For both datasets our method resamples latent variables with cross-entropy greater than 5, this correspond to the percentile 90 in holdout dataset.
#
# Pixel-wise anomaly score is obtained comparing in pixel space the original image with the restorations, specifically:
#
# $$Score_{pixel} = \sum_{j=1}^S \varphi_j\|y-r_j\|_{1}$$
#
# Where $y$ is the test image pixel intensity, $r_j$ the pixel intensity for the restoration $j$ ∈ 1,2,...,S. We noted that the increase in samples contributes to reduce the variance of anomaly predictors, 15 samples are used in the submission.
#
# Given the sequential sampling by the AR model we observed that some of the samples drift too much from the original image and contribute negatively to the anomaly localization. In order to address this issue, we introduced the weighting factor $\varphi$ defined as:
#
#
# $$\varphi_j = \text{softmax}(1/\sum_{i=1}^D\|y^i-r^i_j\|_{1})$$
#
# Where the sum is over D pixels in the original pixel space. Note that this factor weights restorations based on the inverse of the distance between restorations and image, removing weight from restorations that are too different from the original image. Also note that modifying the softmax temperature allows the pixel score to transition from the mean of residuals among restorations to the residuals of the nearest restoration. In submission we use 3. as temperature because it seems to work best in the toy examples. Note that the introduction of the weight has a higher impact in the Abdominal dataset where restorations have a higher variance

# %%
def restore(model, n, img, cond = None, threshold_log_p = 5):
    """ Generate n restorations of images
        Returns restorations, both images and codes """
    
    model.eval()
        
    #Use VQ-VAE to encode original image
    codes = model.retrieve_codes(img,cond)
    code_size = codes.shape[-2:]
    
    with torch.no_grad():

        samples = codes.clone().unsqueeze(1).repeat(1,n,1,1).reshape(img.shape[0]*n,*code_size)
        cond_repeat = cond.unsqueeze(1).repeat(1,n,1).reshape(img.shape[0]*n,-1)
        
        # Iterate through latent variables. 
        for r in range(code_size[0]):
            for c in range(code_size[1]):

                logits = model.forward_latent(samples, cond_repeat)[:, :, r, c]
                loss = F.cross_entropy(logits, samples[:, r, c], reduction='none')

                # Replace sample if above threshold
                probs = F.softmax(logits, dim=1)
                samples[loss > threshold_log_p, r, c] = torch.multinomial(probs, 1).squeeze(-1)[loss > threshold_log_p]
        
        # Retrieve z for the latent codes
        z = model.feature_extractor_model.codebook.embedding(samples.unsqueeze(1))
        z = z.squeeze(1).permute(0,3,1,2).contiguous()
        
        # Decode to pixel space splitting computation in batches
        x_tilde = []
        for i in range(img.shape[0]):
            x_tilde.append(model.feature_extractor_model.decode(z[i*n:(i+1)*n],
                                               cond_repeat[i*n:(i+1)*n]))
        x_tilde = torch.cat(x_tilde)
              
    return x_tilde.reshape(img.shape[0],n,*img.shape[-2:]), samples.reshape(img.shape[0],n,*code_size)

mood_test_reconstructions = []
for X in mood_test:

    img = torch.from_numpy(X.img.copy()).to(device).float()
    coord = torch.from_numpy(X.coord.copy()).to(device).float()

    x_tilde, latent_sample = restore(model,n=15,img=img, cond=coord, threshold_log_p=5)
    mood_test_reconstructions.append(x_tilde)

# %%
img = torch.from_numpy(np.concatenate([x.img for x in mood_test]))
img_tilde = torch.cat(mood_test_reconstructions)
img_seg = torch.from_numpy(np.concatenate(mood_test_seg))

# %%
# (4 volumes x 32 slices, 15 restorations, 160,160)
print(img_tilde.shape)

# (4 volumes x 32 slices,160,160)
print(img_seg.shape)

# %% [markdown]
# Visually compare original image with restoration:

# %%
img_no = 1
slice_no = 9

fig, ax = plt.subplots(2,6, figsize=(8,2.5))
ax[0,0].imshow(mood_test[img_no].img[slice_no])
ax[0,0].axis('off')
ax[1,0].imshow(mood_test_seg[img_no][slice_no])
ax[1,0].axis('off')

for i in range(1,6):
    ax[0,i].imshow(mood_test_reconstructions[img_no][slice_no,i-1].cpu())
    ax[0,i].axis('off')

for i in range(1,6):
    ax[1,i].imshow(mood_test_reconstructions[img_no][slice_no,i-1+5].cpu())
    ax[1,i].axis('off')
plt.tight_layout()

# %% [markdown]
# L1(original image, restoration)

# %%
fig, ax = plt.subplots(2,6, figsize=(8,4))
ax[0,0].imshow(mood_test[img_no].img[slice_no])
ax[0,0].axis('off')
ax[1,0].imshow(mood_test_seg[img_no][slice_no])
ax[1,0].axis('off')
for i in range(1,6):
    tmp = np.abs(mood_test_reconstructions[img_no][slice_no,i-1].cpu() - mood_test[img_no].img[slice_no])
    ax[0,i].imshow(tmp,vmax=2)
    ax[0,i].axis('off')
for i in range(1,6):
    tmp = np.abs(mood_test_reconstructions[img_no][slice_no,i-1+5].cpu()- mood_test[img_no].img[slice_no])
    ax[1,i].imshow(tmp,vmax=2)    
    ax[1,i].axis('off')
plt.tight_layout()

# %%
# Post-processing of predictions
# Restorations are not as sharp as the original images which causes edges to have high variance. MinPooling is 
# used to smooth the edges (-MaxPooling(-x))

smooth = nn.Sequential(nn.MaxPool3d(kernel_size=3,padding=1,stride=1),
                       nn.AvgPool3d(kernel_size=(3,7,7),padding=(1,3,3),stride=1),
                      ).to(device)

# %%
# L1 distance restoration vs original image
diffs = torch.abs(img.unsqueeze(1).to(device).float()-img_tilde)

# Calculate restoration weight based on restoration similarity to original image
sim_imgwise = torch.mean(diffs,(2,3)).unsqueeze(2).unsqueeze(3)
sim_imgwise = torch.softmax(3/sim_imgwise,1)

# Pixel-wise score after weight 
diffs = (diffs*sim_imgwise).sum(1,keepdims=True)

# Post-process using Min Pool and average filter
diffs = diffs.squeeze().unsqueeze(0).unsqueeze(0)
smooth_diffs = -smooth(-diffs)
smooth_diffs = smooth_diffs.squeeze().unsqueeze(1)

# Average precission
metrics.average_precision_score(img_seg.flatten(),smooth_diffs.flatten().clamp_max(1.).cpu() / 1.)

# %%
# ROCAUC
fpr, tpr, thresholds = metrics.roc_curve(img_seg.flatten(), smooth_diffs.flatten().cpu())
metrics.auc(fpr, tpr)

# %%
# Dice Score
utils.max_score(img_seg.flatten(),smooth_diffs.flatten().cpu(), steps = 20)[0].item()

# %%
fig, ax = plt.subplots(1,4, figsize=(6,4))
ax[0].imshow(mood_test[img_no].img[slice_no])
ax[0].axis('off')
ax[1].imshow(mood_test_seg[img_no][slice_no])
ax[1].axis('off')
ax[1].set_title('Segmentation')
ax[2].imshow(diffs.squeeze()[img_no * 32 + slice_no].cpu())
ax[2].axis('off')
ax[2].set_title('Score')
ax[3].imshow(smooth_diffs[img_no * 32 + slice_no].squeeze().cpu())
ax[3].axis('off')
ax[3].set_title('Smoothed score')

plt.tight_layout()

# %%
# Anomaly score histogram, anomalous vs normal
plt.hist(smooth_diffs.flatten().cpu()[img_seg.flatten()==0],alpha=.3,bins=20,density=True)
plt.hist(smooth_diffs.flatten().cpu()[img_seg.flatten()==1],alpha=.3,bins=20,density=True)
plt.xscale('log')
plt.yscale('log')
